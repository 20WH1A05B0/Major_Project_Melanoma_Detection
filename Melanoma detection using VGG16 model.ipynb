# %%
import os    
#import cv2# for working with files
import numpy as np              # for numerical computationss
import pandas as pd             # for working with dataframes
import seaborn as sns
import torch                    # Pytorch module 
import matplotlib.pyplot as plt # for plotting informations on graph and images using tensors
import torch.nn as nn           # for creating  neural networks
from torch.utils.data import DataLoader # for dataloaders 
from PIL import Image          # for checking images
import torch.nn.functional as F # for functions for calculating loss
import torchvision.transforms as transforms   # for transforming images into tensors 
from torchvision.utils import make_grid       # for data checking
from torchvision.datasets import ImageFolder  # for working with classes and images
from torchsummary import summary              # for getting the summary of our model
import tensorflow as ts 
from  tensorflow import keras
import itertools
from sklearn.metrics import precision_score, accuracy_score, recall_score, confusion_matrix, ConfusionMatrixDisplay
#from tensorflow.keras.applications.vgg16 import VGG16

# %matplotlib inline

# %%
from tensorflow.keras.applications.vgg16 import VGG16

# %%
train_dir = "Batch 1/Train1"
skin = os.listdir(train_dir)

# %%
# Construct the full path to the image
#from PIL import Image

# Open an image file
#image_path = 'Batch 1/Train/Benign/melanoma_1.jpg'
#image = Image.open(image_path)

# Display the image if needed
#plt.imshow(image)
#print(image.shape)

# %%
# Number of images for each disease
nums_train = {}
nums_val = {}
for s in skin:
    nums_train[s] = len(os.listdir(train_dir + '/' + s))
img_per_class_train = pd.DataFrame(nums_train.values(), index=nums_train.keys(), columns=["no. of images"])
print('Train data distribution :')
img_per_class_train
# Out:
# Train data distribution :
#                     no. of images
# .ipynb_checkpoints              0
# Benign1                      5001
# Malignant1                   4606

# %%
#pip install opencv-python

# %%
plt.figure(figsize=(10,10))
plt.title('data distribution ',fontsize=30)
plt.ylabel('Number of image',fontsize=20)
plt.xlabel('Type of skin cancer',fontsize=20)

keys = list(nums_train.keys())
vals = list(nums_train.values())
sns.barplot(x=keys, y=vals)
# Out:
# <AxesSubplot:title={'center':'data distribution '}, xlabel='Type of skin cancer', ylabel='Number of image'>

# %%
train_gen = keras.preprocessing.image.ImageDataGenerator(rescale=1./255,
                                                         rotation_range = 20 ,
                                                         horizontal_flip = True ,
                                                         validation_split = 0.25
                                                         )
classes = ['Benign1', 'Malignant1']
valid_gen =  keras.preprocessing.image.ImageDataGenerator(rescale=1./255,validation_split = 0.25)
train_data = train_gen.flow_from_directory(train_dir, subset='training', target_size=(224,224),
                                           batch_size=64, color_mode='rgb', 
                                            class_mode='categorical', shuffle=True,classes=classes)

test_data = valid_gen.flow_from_directory(train_dir, subset='validation', target_size=(224,224),
                                          batch_size=64, color_mode='rgb', 
                                            class_mode='categorical', shuffle=False,classes=classes)
# Out:
# Found 7205 images belonging to 2 classes.
# Found 2401 images belonging to 2 classes.

# %%
# Get the first batch of images and labels from the training generator
batch_images, batch_labels = next(train_data)

# Get the first image and its corresponding label
first_image = batch_images[0]
first_label = batch_labels[0]
plt.imshow(first_image)

# Display or process the first image and label as needed
print("First Image Shape:", first_image.shape)
print("First Label:", first_label)
# Out:
# First Image Shape: (224, 224, 3)
# First Label: [0. 1.]

# %%
train_steps = train_data.n//train_data.batch_size
print(train_steps)
# Out:
# 112

# %%
test_steps = test_data.n//test_data.batch_size
print(test_steps)
# Out:
# 37

# %%
vvg = VGG16(input_shape=(224,224, 3), include_top=False,weights = 'imagenet')

# %%
for layers in (vvg.layers):
    layers.trainable = False

# %%
vvg.layers
# Out:
# [<tensorflow.python.keras.engine.input_layer.InputLayer at 0x7f8c24162c50>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f8c24199a90>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f8c24199d30>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f8c24199400>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f8c241f43c8>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f8c24206208>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f8c24206320>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f8c241e8390>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f8c241d23c8>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f8c241d2748>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f8c241f6940>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f8c284062e8>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f8c28406ba8>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f8c2438d9e8>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f8c283eedd8>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f8c283d4860>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f8c283f9b38>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f8c283f9358>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f8c283e6198>]

# %%
vvg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras.models import Sequential
from keras.layers import Flatten
from keras.layers import Dense,Dropout
model = Sequential()


model.add(vvg)
# Add new layers
model.add(Flatten())
model.add(Dense(4096 , activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096 , activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2, activation='softmax'))

model.summary()
from tensorflow.keras.optimizers import Adam ,RMSprop
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 8194
# =================================================================
# Total params: 151,050,050
# Trainable params: 136,335,362
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
lr = 1e-6
model.compile(loss='categorical_crossentropy', optimizer=Adam(lr), metrics=['accuracy'])

# %%
mcp = ModelCheckpoint('modelVVG_35.h5', verbose=1)

# %%
es = EarlyStopping(patience=5,verbose=1)

# %%
history = model.fit(train_data,steps_per_epoch=train_steps,epochs=35,validation_data=test_data,validation_steps=test_steps,verbose=1,callbacks=[mcp,es])
# Out:
# Epoch 1/35
# 112/112 [==============================] - ETA: 0s - loss: 0.7074 - accuracy: 0.5680
# Epoch 00001: saving model to modelVVG_35.h5
# 112/112 [==============================] - 296s 3s/step - loss: 0.7074 - accuracy: 0.5680 - val_loss: 0.5708 - val_accuracy: 0.6934
# Epoch 2/35
# 112/112 [==============================] - ETA: 0s - loss: 0.6300 - accuracy: 0.6443
# Epoch 00002: saving model to modelVVG_35.h5
# 112/112 [==============================] - 349s 3s/step - loss: 0.6300 - accuracy: 0.6443 - val_loss: 0.5139 - val_accuracy: 0.7209
# Epoch 3/35
# 112/112 [==============================] - ETA: 0s - loss: 0.5621 - accuracy: 0.7040
# Epoch 00003: saving model to modelVVG_35.h5
# 112/112 [==============================] - 323s 3s/step - loss: 0.5621 - accuracy: 0.7040 - val_loss: 0.4553 - val_accuracy: 0.7842
# Epoch 4/35
# 112/112 [==============================] - ETA: 0s - loss: 0.5289 - accuracy: 0.7278
# Epoch 00004: saving model to modelVVG_35.h5
# 112/112 [==============================] - 308s 3s/step - loss: 0.5289 - accuracy: 0.7278 - val_loss: 0.4210 - val_accuracy: 0.8062
# Epoch 5/35
# 112/112 [==============================] - ETA: 0s - loss: 0.4980 - accuracy: 0.7549
# Epoch 00005: saving model to modelVVG_35.h5
# 112/112 [==============================] - 308s 3s/step - loss: 0.4980 - accuracy: 0.7549 - val_loss: 0.3894 - val_accuracy: 0.8273
# Epoch 6/35
# 112/112 [==============================] - ETA: 0s - loss: 0.4695 - accuracy: 0.7730
# Epoch 00006: saving model to modelVVG_35.h5
# 112/112 [==============================] - 346s 3s/step - loss: 0.4695 - accuracy: 0.7730 - val_loss: 0.3726 - val_accuracy: 0.8319
# Epoch 7/35
# 112/112 [==============================] - ETA: 0s - loss: 0.4524 - accuracy: 0.7885
# Epoch 00007: saving model to modelVVG_35.h5
# 112/112 [==============================] - 329s 3s/step - loss: 0.4524 - accuracy: 0.7885 - val_loss: 0.3505 - val_accuracy: 0.8560
# Epoch 8/35
# 112/112 [==============================] - ETA: 0s - loss: 0.4334 - accuracy: 0.8003
# Epoch 00008: saving model to modelVVG_35.h5
# 112/112 [==============================] - 351s 3s/step - loss: 0.4334 - accuracy: 0.8003 - val_loss: 0.3458 - val_accuracy: 0.8514
# Epoch 9/35
# 112/112 [==============================] - ETA: 0s - loss: 0.4185 - accuracy: 0.8100
# Epoch 00009: saving model to modelVVG_35.h5
# 112/112 [==============================] - 349s 3s/step - loss: 0.4185 - accuracy: 0.8100 - val_loss: 0.3371 - val_accuracy: 0.8539
# Epoch 10/35
# 112/112 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.8139
# Epoch 00010: saving model to modelVVG_35.h5
# 112/112 [==============================] - 290s 3s/step - loss: 0.4132 - accuracy: 0.8139 - val_loss: 0.3285 - val_accuracy: 0.8598
# Epoch 11/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3933 - accuracy: 0.8258
# Epoch 00011: saving model to modelVVG_35.h5
# 112/112 [==============================] - 295s 3s/step - loss: 0.3933 - accuracy: 0.8258 - val_loss: 0.3406 - val_accuracy: 0.8467
# Epoch 12/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3830 - accuracy: 0.8303
# Epoch 00012: saving model to modelVVG_35.h5
# 112/112 [==============================] - 310s 3s/step - loss: 0.3830 - accuracy: 0.8303 - val_loss: 0.3197 - val_accuracy: 0.8615
# Epoch 13/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3737 - accuracy: 0.8325
# Epoch 00013: saving model to modelVVG_35.h5
# 112/112 [==============================] - 348s 3s/step - loss: 0.3737 - accuracy: 0.8325 - val_loss: 0.3144 - val_accuracy: 0.8649
# Epoch 14/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3623 - accuracy: 0.8426
# Epoch 00014: saving model to modelVVG_35.h5
# 112/112 [==============================] - 289s 3s/step - loss: 0.3623 - accuracy: 0.8426 - val_loss: 0.3222 - val_accuracy: 0.8598
# Epoch 15/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3593 - accuracy: 0.8434
# Epoch 00015: saving model to modelVVG_35.h5
# 112/112 [==============================] - 328s 3s/step - loss: 0.3593 - accuracy: 0.8434 - val_loss: 0.3044 - val_accuracy: 0.8716
# Epoch 16/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3589 - accuracy: 0.8418
# Epoch 00016: saving model to modelVVG_35.h5
# 112/112 [==============================] - 353s 3s/step - loss: 0.3589 - accuracy: 0.8418 - val_loss: 0.2981 - val_accuracy: 0.8712
# Epoch 17/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3425 - accuracy: 0.8485
# Epoch 00017: saving model to modelVVG_35.h5
# 112/112 [==============================] - 350s 3s/step - loss: 0.3425 - accuracy: 0.8485 - val_loss: 0.2996 - val_accuracy: 0.8699
# Epoch 18/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3397 - accuracy: 0.8534
# Epoch 00018: saving model to modelVVG_35.h5
# 112/112 [==============================] - 346s 3s/step - loss: 0.3397 - accuracy: 0.8534 - val_loss: 0.2946 - val_accuracy: 0.8750
# Epoch 19/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3411 - accuracy: 0.8537
# Epoch 00019: saving model to modelVVG_35.h5
# 112/112 [==============================] - 337s 3s/step - loss: 0.3411 - accuracy: 0.8537 - val_loss: 0.2990 - val_accuracy: 0.8729
# Epoch 20/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3297 - accuracy: 0.8590
# Epoch 00020: saving model to modelVVG_35.h5
# 112/112 [==============================] - 290s 3s/step - loss: 0.3297 - accuracy: 0.8590 - val_loss: 0.2852 - val_accuracy: 0.8784
# Epoch 21/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3290 - accuracy: 0.8562
# Epoch 00021: saving model to modelVVG_35.h5
# 112/112 [==============================] - 284s 3s/step - loss: 0.3290 - accuracy: 0.8562 - val_loss: 0.2810 - val_accuracy: 0.8784
# Epoch 22/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3209 - accuracy: 0.8630
# Epoch 00022: saving model to modelVVG_35.h5
# 112/112 [==============================] - 293s 3s/step - loss: 0.3209 - accuracy: 0.8630 - val_loss: 0.2856 - val_accuracy: 0.8788
# Epoch 23/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3236 - accuracy: 0.8644
# Epoch 00023: saving model to modelVVG_35.h5
# 112/112 [==============================] - 308s 3s/step - loss: 0.3236 - accuracy: 0.8644 - val_loss: 0.2873 - val_accuracy: 0.8771
# Epoch 24/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3165 - accuracy: 0.8623
# Epoch 00024: saving model to modelVVG_35.h5
# 112/112 [==============================] - 323s 3s/step - loss: 0.3165 - accuracy: 0.8623 - val_loss: 0.2854 - val_accuracy: 0.8780
# Epoch 25/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3118 - accuracy: 0.8684
# Epoch 00025: saving model to modelVVG_35.h5
# 112/112 [==============================] - 344s 3s/step - loss: 0.3118 - accuracy: 0.8684 - val_loss: 0.2755 - val_accuracy: 0.8801
# Epoch 26/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3031 - accuracy: 0.8761
# Epoch 00026: saving model to modelVVG_35.h5
# 112/112 [==============================] - 359s 3s/step - loss: 0.3031 - accuracy: 0.8761 - val_loss: 0.2814 - val_accuracy: 0.8796
# Epoch 27/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3048 - accuracy: 0.8721
# Epoch 00027: saving model to modelVVG_35.h5
# 112/112 [==============================] - 361s 3s/step - loss: 0.3048 - accuracy: 0.8721 - val_loss: 0.2740 - val_accuracy: 0.8813
# Epoch 28/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3055 - accuracy: 0.8691
# Epoch 00028: saving model to modelVVG_35.h5
# 112/112 [==============================] - 359s 3s/step - loss: 0.3055 - accuracy: 0.8691 - val_loss: 0.2692 - val_accuracy: 0.8847
# Epoch 29/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.8723
# Epoch 00029: saving model to modelVVG_35.h5
# 112/112 [==============================] - 357s 3s/step - loss: 0.3005 - accuracy: 0.8723 - val_loss: 0.2734 - val_accuracy: 0.8839
# Epoch 30/35
# 112/112 [==============================] - ETA: 0s - loss: 0.3001 - accuracy: 0.8730
# Epoch 00030: saving model to modelVVG_35.h5
# 112/112 [==============================] - 340s 3s/step - loss: 0.3001 - accuracy: 0.8730 - val_loss: 0.2717 - val_accuracy: 0.8843
# Epoch 31/35
# 112/112 [==============================] - ETA: 0s - loss: 0.2927 - accuracy: 0.8791
# Epoch 00031: saving model to modelVVG_35.h5
# 112/112 [==============================] - 268s 2s/step - loss: 0.2927 - accuracy: 0.8791 - val_loss: 0.2783 - val_accuracy: 0.8805
# Epoch 32/35
# 112/112 [==============================] - ETA: 0s - loss: 0.2900 - accuracy: 0.8779
# Epoch 00032: saving model to modelVVG_35.h5
# 112/112 [==============================] - 266s 2s/step - loss: 0.2900 - accuracy: 0.8779 - val_loss: 0.2768 - val_accuracy: 0.8805
# Epoch 33/35
# 112/112 [==============================] - ETA: 0s - loss: 0.2910 - accuracy: 0.8751
# Epoch 00033: saving model to modelVVG_35.h5
# 112/112 [==============================] - 277s 2s/step - loss: 0.2910 - accuracy: 0.8751 - val_loss: 0.2871 - val_accuracy: 0.8805
# Epoch 00033: early stopping

# %%
model.evaluate(test_data, verbose=1, steps=test_steps)
# Out:
# 37/37 [==============================] - 59s 2s/step - loss: 0.2871 - accuracy: 0.8805
# [0.28708332777023315, 0.8804898858070374]

# %%
import matplotlib.pyplot as plt

accuracy      = history.history['accuracy']
val_accuracy  = history.history['val_accuracy']
loss     = history.history['loss']
val_loss = history.history['val_loss']

epochs   = range(len(accuracy))

plt.figure(num=None, figsize=(10, 8), dpi=300, facecolor='w', edgecolor='k')
sns.set(style="white")
plt.plot(epochs, accuracy,label = "Training Accuracy")
plt.plot(epochs, val_accuracy, label = "Validation Accuracy")
plt.ylabel('Accuracy',fontsize=20)
plt.xlabel('Epochs',fontsize=20)
plt.title('\n Training and validation accuracy',fontsize = 20)
plt.legend()
plt.savefig('Accuracy.png',dpi=400,bbox_inches='tight')
plt.show()

# Plot training and validation loss per epoch
plt.figure(num=None, figsize=(10, 8), dpi=300, facecolor='w', edgecolor='k')
sns.set(style="white")
plt.plot(epochs, loss, label = 'Training Loss')
plt.plot(epochs, val_loss, label = "Validation Loss")
plt.ylabel('Loss',fontsize=20)
plt.xlabel('Epochs',fontsize=20)
plt.title('\n Training and validation loss', fontsize = 20)
plt.legend()
plt.savefig('Loss.png',dpi=400,bbox_inches='tight')
plt.show()

# %%
from keras.models import load_model
model = load_model('modelVVG_35.h5')

# %%
from sklearn.metrics import classification_report

Y_pred = model.predict(test_data)
y_pred = np.argmax(Y_pred, axis=1)

print(classification_report(test_data.classes, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.89      1250
#            1       0.94      0.80      0.86      1151
#
#     accuracy                           0.88      2401
#    macro avg       0.89      0.88      0.88      2401
# weighted avg       0.89      0.88      0.88      2401

# %%
train_data.class_indices
# Out:
# {'Benign1': 0, 'Malignant1': 1}

# %%
test_data.class_indices
# Out:
# {'Benign1': 0, 'Malignant1': 1}

# %%
from keras.preprocessing import image
import numpy as np
from PIL import Image  
from keras.models import load_model
model = load_model('modelVVG_35.h5')

# Step 2: Preprocess the test image
test_image_path = 'Batch 1/Train1/Malignant1/melanoma_6078.jpg'  # Change this to the path of your test image
test_image = image.load_img(test_image_path, target_size=(224, 224))  # Assuming VGG11 model requires input size of 224x224
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
test_image = test_image / 255.  # Normalize the pixel values to the range [0, 1]

predictions = model.predict(test_image)
img = Image.open(test_image_path)
display(img)
# Step 3: Make predictions on the preprocessed test image
predictions = model.predict(test_image)

# Convert predictions to class labels (assuming binary classification)
predicted_class = 'No Melanoma' if predictions[0][0] > predictions[0][1] else 'Melanoma'  # Assuming two classes (0 and 1)  # Adjust this according to your class labels

print("Predicted class:", predicted_class)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7FC8F85F2630>
# Predicted class: Melanoma

# %%
from keras.preprocessing import image
import numpy as np
from keras.models import load_model
model = load_model('modelVVG_35.h5')

# Step 2: Preprocess the test image
test_image_path = 'Batch 1/Train1/Benign1/melanoma_178.jpg'  # Change this to the path of your test image
test_image = image.load_img(test_image_path, target_size=(224, 224))  # Assuming VGG11 model requires input size of 224x224
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
test_image = test_image / 255.  # Normalize the pixel values to the range [0, 1]

predictions = model.predict(test_image)
img = Image.open(test_image_path)
display(img)
# Step 3: Make predictions on the preprocessed test image
predictions = model.predict(test_image)

# Convert predictions to class labels (assuming binary classification)
predicted_class = 'No Melanoma' if predictions[0][0] > predictions[0][1] else 'Melanoma'  # Assuming two classes (0 and 1)  # Adjust this according to your class labels

print("Predicted class:", predicted_class)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7FC9C31D3198>
# Predicted class: No Melanoma

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
from tensorflow.keras.models import load_model
from PIL import Image

def classify_image(model_path, test_image_path, target_size=(224, 224)):
  """
  Loads a pre-trained model, preprocesses a test image, makes predictions,
  and returns the predicted class label.

  Args:
      model_path (str): Path to the saved model file (e.g., 'modelVVG_35.h5').
      test_image_path (str): Path to the test image file.
      target_size (tuple, optional): Target size for image resizing. Defaults to (224, 224).

  Returns:
      str: The predicted class label.
  """

  # Load the pre-trained model
  model = load_model(model_path)

  # Preprocess the test image
  test_image = image.load_img(test_image_path, target_size=target_size)
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis=0)
  test_image = test_image / 255.0  # Normalize pixel values

  # Make predictions on the preprocessed test image
  predictions = model.predict(test_image)

  # Convert predictions to class labels (assuming binary classification)
  predicted_class = 'No Melanoma' if predictions[0][0] > predictions[0][1] else 'Melanoma'

  return predicted_class

# Example usage
model_path = 'modelVVG_35.h5'
test_image_path = 'Batch 1/Train1/Benign1/melanoma_100.jpg'
predicted_class = classify_image(model_path, test_image_path)
print("Predicted class:", predicted_class)
# Display the image using PIL
try:
  img = Image.open(test_image_path)
  img.show()  # Display the image
except FileNotFoundError:
  print(f"Error: Image file '{test_image_path}' not found.")
# Out:
# Predicted class: No Melanoma
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F240C4A5F98>

# %%
from tensorflow.keras.preprocessing import image  # Import for image processing
import numpy as np
from tensorflow.keras.models import load_model
from PIL import Image  # Import for image display

def classify_image(model_path, test_image_path, target_size=(224, 224)):
  """
  Loads a pre-trained model, preprocesses a test image, makes predictions,
  and returns the predicted class label. Also displays the image.

  Args:
      model_path (str): Path to the saved model file (e.g., 'modelVVG_35.h5').
      test_image_path (str): Path to the test image file.
      target_size (tuple, optional): Target size for image resizing. Defaults to (224, 224).

  Returns:
      str: The predicted class label.
  """

  # Load the pre-trained model
  model = load_model(model_path)

  # Preprocess the test image
  test_image = image.load_img(test_image_path, target_size=target_size)
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis=0)
  test_image = test_image / 255.0  # Normalize pixel values

  # Make predictions on the preprocessed test image
  predictions = model.predict(test_image)

  # Convert predictions to class labels (assuming binary classification)
  predicted_class = 'No Melanoma' if predictions[0][0] > predictions[0][1] else 'Melanoma'

  # Display the image
  try:
    img = Image.open(test_image_path)
    img.show()  # Display the image
  except FileNotFoundError:
    print(f"Error: Image file '{test_image_path}' not found.")

  return predicted_class

# Example usage
model_path = 'modelVVG_35.h5'
test_image_path = 'Batch 1/Train1/Malignant1/melanoma_6000.jpg'
predicted_class = classify_image(model_path, test_image_path)
print("Predicted class:", predicted_class)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F240C311198>
# Predicted class: Melanoma
